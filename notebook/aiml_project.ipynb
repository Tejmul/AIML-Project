# %%
# !pip install -q opencv-python pandas numpy pillow scikit-learn torch torchvision timm matplotlib seaborn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 111.1 MB/s eta 0:00:00

# %%
import cv2
import os
import json
import numpy as np
import torch
import torchvision.transforms as transforms
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
import timm
import shutil

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %%
BASE_PATH = "/content"
VIDEO_DIR = f"{BASE_PATH}"
FRAMES_RAW_DIR = f"{BASE_PATH}/frames_raw"  # ALL frames extracted
FRAMES_QUANTIZED_DIR = f"{BASE_PATH}/frames_quantized"  # Quantized frames
OUTPUT_DIR = f"{BASE_PATH}/results"

# Create directories
os.makedirs(FRAMES_RAW_DIR, exist_ok=True)
os.makedirs(FRAMES_QUANTIZED_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Configuration
FRAME_SIZE = (224, 224)
FRAME_SKIP_FOR_QUANTIZATION = 3  # Extract 1 frame every 3 frames for analysis

print("="*60)
print("📁 CONFIGURATION SETUP")
print("="*60)
print(f"✅ Video Directory: {VIDEO_DIR}")
print(f"✅ Raw Frames Directory: {FRAMES_RAW_DIR}")
print(f"✅ Quantized Frames Directory: {FRAMES_QUANTIZED_DIR}")
print(f"✅ Output Directory: {OUTPUT_DIR}")
print(f"✅ Frame Size: {FRAME_SIZE}")
print(f"✅ Quantization: 1 frame every {FRAME_SKIP_FOR_QUANTIZATION} frames")
print("="*60)
# Out:
# ============================================================
# 📁 CONFIGURATION SETUP
# ============================================================
# ✅ Video Directory: /content
# ✅ Raw Frames Directory: /content/frames_raw
# ✅ Quantized Frames Directory: /content/frames_quantized
# ✅ Output Directory: /content/results
# ✅ Frame Size: (224, 224)
# ✅ Quantization: 1 frame every 3 frames
# ============================================================

# %%
def extract_all_frames(video_path, output_dir, frame_size=(224, 224)):
    """
    Extract ALL frames from video without any skipping
    Shows professor you processed EVERYTHING
    """
    video_name = os.path.basename(video_path).replace('.avi', '').replace('.mp4', '')
    output_subdir = os.path.join(output_dir, video_name)
    os.makedirs(output_subdir, exist_ok=True)

    cap = cv2.VideoCapture(video_path)

    # Get video info
    video_fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames_in_video = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if video_fps == 0:
        video_fps = 30  # Default fallback

    frame_count = 0
    extracted_count = 0

    print(f"\n📹 Processing: {video_name}")
    print(f"   FPS: {video_fps:.1f} | Total Frames: {total_frames_in_video}")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize frame
        frame_resized = cv2.resize(frame, frame_size)

        # Save every frame
        output_path = os.path.join(output_subdir, f"frame_{extracted_count:06d}.jpg")
        cv2.imwrite(output_path, frame_resized)

        extracted_count += 1
        frame_count += 1

        # Progress indicator
        if extracted_count % 1000 == 0:
            print(f"   ✅ Extracted {extracted_count} frames...")

    cap.release()

    return extracted_count, video_fps, total_frames_in_video

# %%
# Clear previous frames
print("\n🗑️  Clearing previous frame directories...")
if os.path.exists(FRAMES_RAW_DIR):
    shutil.rmtree(FRAMES_RAW_DIR)
os.makedirs(FRAMES_RAW_DIR, exist_ok=True)
# Out:
# 🗑️  Clearing previous frame directories...

# %%
# Find all video files
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith(('.avi', '.mp4', '.MOV'))]
print(f"\n🎬 Found {len(video_files)} video file(s)")

if len(video_files) == 0:
    print("❌ No video files found! Please upload videos to /content/")
else:
    print("\n" + "="*60)
    print("📹 PHASE 1: EXTRACTING ALL FRAMES (NO QUANTIZATION)")
    print("="*60)

    total_stats = {'raw_extracted': 0, 'total_fps': 0}
    video_info_map = {}

    for video_file in video_files:
        video_path = os.path.join(VIDEO_DIR, video_file)
        extracted, fps, total = extract_all_frames(video_path, FRAMES_RAW_DIR)
        total_stats['raw_extracted'] += extracted
        total_stats['total_fps'] = fps
        video_info_map[video_file] = {'extracted': extracted, 'fps': fps}
        print(f"   ✅ Extracted: {extracted} frames")

    print("\n" + "="*60)
    print(f"✅ PHASE 1 COMPLETE - ALL FRAMES EXTRACTED")
    print("="*60)
    print(f"📊 Total frames extracted (RAW): {total_stats['raw_extracted']}")
    print(f"   Video FPS used: {total_stats['total_fps']}")
    print("="*60)
# Out:
# 🎬 Found 254 video file(s)
#
# ============================================================
# 📹 PHASE 1: EXTRACTING ALL FRAMES (NO QUANTIZATION)
# ============================================================
#
# 📹 Processing: cctv052x2004080520x01699
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080609x01871
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01656
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01874
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080607x01848
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01849
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080617x00069
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080617x00067
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01915
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01912
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080520x01695
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080614x00019
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01858
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01866
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080610x01877
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080608x01854
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00070
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00062
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01666
#    FPS: 10.0 | Total Frames: 54
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080616x00048
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 49 frames
#
# 📹 Processing: cctv052x2004080518x01677
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01821
#    FPS: 10.0 | Total Frames: 51
#    ✅ Extracted: 47 frames
#
# 📹 Processing: cctv052x2004080619x00100
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080519x01681
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080620x00107
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01898
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00087
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01832
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00075
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01644
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00007
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080610x01885
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01900
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080611x01905
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01669
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00041
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00101
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01856
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01653
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01907
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080609x01872
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01857
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01875
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080609x01862
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080615x00033
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01820
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01678
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00000
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01909
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01645
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080606x01829
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01641
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080606x01830
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080614x00023
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080613x00009
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080617x00065
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00096
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01892
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01878
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01828
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080613x00011
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080614x00025
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01863
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080614x00022
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01826
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01836
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01687
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080606x01827
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080616x00060
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01840
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080614x00027
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01693
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01841
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01897
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01655
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01864
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080620x00105
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080516x01648
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00099
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00081
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01851
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080606x01824
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00077
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01831
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01855
#    FPS: 10.0 | Total Frames: 54
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080519x01691
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080606x01823
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080517x01661
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01822
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080613x00015
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080620x00108
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080613x00017
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00088
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01903
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00053
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00079
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01908
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00052
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01665
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00056
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01845
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01904
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01673
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080613x00014
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00086
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00059
#    FPS: 10.0 | Total Frames: 51
#    ✅ Extracted: 48 frames
#
# 📹 Processing: cctv052x2004080607x01847
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080612x01911
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 48 frames
#
# 📹 Processing: cctv052x2004080611x01899
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080614x00024
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00034
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01649
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01886
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00064
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080619x00094
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01690
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080607x01837
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00061
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00091
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01867
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00058
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01684
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01642
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080615x00031
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00054
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01865
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01663
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00057
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00076
#    FPS: 10.0 | Total Frames: 47
#    ✅ Extracted: 43 frames
#
# 📹 Processing: cctv052x2004080609x01859
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00005
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01896
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01879
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00030
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00049
#    FPS: 10.0 | Total Frames: 49
#    ✅ Extracted: 44 frames
#
# 📹 Processing: cctv052x2004080517x01658
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00072
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080615x00039
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080520x01697
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01667
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080619x00103
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01869
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080613x00008
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080519x01683
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080618x00080
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01676
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01834
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00095
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080614x00020
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01887
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00068
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080618x00089
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01688
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01639
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080520x01700
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01906
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080613x00013
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00040
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01662
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01659
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00055
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00036
#    FPS: 10.0 | Total Frames: 54
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01882
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00002
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080606x01833
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01652
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080613x00010
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01902
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00032
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01839
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01910
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01890
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080516x01647
#    FPS: 10.0 | Total Frames: 54
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080607x01843
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01884
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080518x01674
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01692
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080615x00038
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01671
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00071
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01675
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01660
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01894
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01654
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00047
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x01914
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00028
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00004
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080520x01694
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01686
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 49 frames
#
# 📹 Processing: cctv052x2004080614x00021
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080613x00016
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080619x00092
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01680
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01889
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080519x01679
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00045
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01901
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080610x01891
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080607x01844
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01643
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080620x00106
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00050
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080619x00098
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00090
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080617x00066
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080520x01698
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 51 frames
#
# 📹 Processing: cctv052x2004080608x01852
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01670
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080519x01682
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01880
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01850
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080518x01672
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080613x00018
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080617x00073
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00029
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080612x01913
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01689
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080612x00006
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01640
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 48 frames
#
# 📹 Processing: cctv052x2004080607x01846
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00046
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080611x01895
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00097
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080619x00104
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080618x00085
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01883
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080519x01685
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00093
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01876
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080616x00051
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01646
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 49 frames
#
# 📹 Processing: cctv052x2004080518x01668
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080516x01638
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080608x01853
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080609x01870
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00044
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01861
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080617x00074
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080517x01657
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01873
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080612x00003
#    FPS: 10.0 | Total Frames: 54
#    ✅ Extracted: 50 frames
#
# 📹 Processing: cctv052x2004080607x01835
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00035
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080615x00037
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080517x01664
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080607x01838
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080613x00012
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080610x01881
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080619x00102
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080614x00026
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080609x01860
#    FPS: 10.0 | Total Frames: 52
#    ✅ Extracted: 52 frames
#
# 📹 Processing: cctv052x2004080516x01650
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# 📹 Processing: cctv052x2004080607x01842
#    FPS: 10.0 | Total Frames: 53
#    ✅ Extracted: 53 frames
#
# ============================================================
# ✅ PHASE 1 COMPLETE - ALL FRAMES EXTRACTED
# ============================================================
# 📊 Total frames extracted (RAW): 13317
#    Video FPS used: 10.0
# ============================================================

# %%
# Count frames per video
raw_frame_info = {}
total_raw_frames = 0

print("\n" + "="*60)
print("📊 VERIFYING RAW FRAMES")
print("="*60)

for video_dir in sorted(os.listdir(FRAMES_RAW_DIR)):
    video_path = os.path.join(FRAMES_RAW_DIR, video_dir)
    if os.path.isdir(video_path):
        frame_count = len([f for f in os.listdir(video_path) if f.endswith('.jpg')])
        raw_frame_info[video_dir] = frame_count
        total_raw_frames += frame_count

print(f"\n✅ Total RAW frames extracted: {total_raw_frames}")
print("\n📁 Frames per video:")
for video, count in raw_frame_info.items():
    print(f"   {video}: {count} frames")
# Out:
# ============================================================
# 📊 VERIFYING RAW FRAMES
# ============================================================
#
# ✅ Total RAW frames extracted: 13317
#
# 📁 Frames per video:
#    cctv052x2004080516x01638: 53 frames
#    cctv052x2004080516x01639: 53 frames
#    cctv052x2004080516x01640: 48 frames
#    cctv052x2004080516x01641: 52 frames
#    cctv052x2004080516x01642: 51 frames
#    cctv052x2004080516x01643: 53 frames
#    cctv052x2004080516x01644: 53 frames
#    cctv052x2004080516x01645: 52 frames
#    cctv052x2004080516x01646: 49 frames
#    cctv052x2004080516x01647: 52 frames
#    cctv052x2004080516x01648: 53 frames
#    cctv052x2004080516x01649: 53 frames
#    cctv052x2004080516x01650: 53 frames
#    cctv052x2004080517x01652: 53 frames
#    cctv052x2004080517x01653: 53 frames
#    cctv052x2004080517x01654: 53 frames
#    cctv052x2004080517x01655: 53 frames
#    cctv052x2004080517x01656: 53 frames
#    cctv052x2004080517x01657: 53 frames
#    cctv052x2004080517x01658: 53 frames
#    cctv052x2004080517x01659: 53 frames
#    cctv052x2004080517x01660: 53 frames
#    cctv052x2004080517x01661: 53 frames
#    cctv052x2004080517x01662: 53 frames
#    cctv052x2004080517x01663: 53 frames
#    cctv052x2004080517x01664: 52 frames
#    cctv052x2004080517x01665: 53 frames
#    cctv052x2004080518x01666: 51 frames
#    cctv052x2004080518x01667: 51 frames
#    cctv052x2004080518x01668: 53 frames
#    cctv052x2004080518x01669: 53 frames
#    cctv052x2004080518x01670: 52 frames
#    cctv052x2004080518x01671: 53 frames
#    cctv052x2004080518x01672: 53 frames
#    cctv052x2004080518x01673: 52 frames
#    cctv052x2004080518x01674: 53 frames
#    cctv052x2004080518x01675: 53 frames
#    cctv052x2004080518x01676: 53 frames
#    cctv052x2004080518x01677: 53 frames
#    cctv052x2004080519x01678: 53 frames
#    cctv052x2004080519x01679: 53 frames
#    cctv052x2004080519x01680: 53 frames
#    cctv052x2004080519x01681: 53 frames
#    cctv052x2004080519x01682: 53 frames
#    cctv052x2004080519x01683: 52 frames
#    cctv052x2004080519x01684: 53 frames
#    cctv052x2004080519x01685: 53 frames
#    cctv052x2004080519x01686: 49 frames
#    cctv052x2004080519x01687: 52 frames
#    cctv052x2004080519x01688: 53 frames
#    cctv052x2004080519x01689: 52 frames
#    cctv052x2004080519x01690: 52 frames
#    cctv052x2004080519x01691: 52 frames
#    cctv052x2004080519x01692: 51 frames
#    cctv052x2004080519x01693: 53 frames
#    cctv052x2004080520x01694: 53 frames
#    cctv052x2004080520x01695: 53 frames
#    cctv052x2004080520x01697: 53 frames
#    cctv052x2004080520x01698: 51 frames
#    cctv052x2004080520x01699: 52 frames
#    cctv052x2004080520x01700: 53 frames
#    cctv052x2004080606x01820: 53 frames
#    cctv052x2004080606x01821: 47 frames
#    cctv052x2004080606x01822: 53 frames
#    cctv052x2004080606x01823: 52 frames
#    cctv052x2004080606x01824: 53 frames
#    cctv052x2004080606x01826: 53 frames
#    cctv052x2004080606x01827: 50 frames
#    cctv052x2004080606x01828: 52 frames
#    cctv052x2004080606x01829: 53 frames
#    cctv052x2004080606x01830: 52 frames
#    cctv052x2004080606x01831: 53 frames
#    cctv052x2004080606x01832: 53 frames
#    cctv052x2004080606x01833: 53 frames
#    cctv052x2004080606x01834: 53 frames
#    cctv052x2004080607x01835: 53 frames
#    cctv052x2004080607x01836: 53 frames
#    cctv052x2004080607x01837: 53 frames
#    cctv052x2004080607x01838: 53 frames
#    cctv052x2004080607x01839: 53 frames
#    cctv052x2004080607x01840: 52 frames
#    cctv052x2004080607x01841: 53 frames
#    cctv052x2004080607x01842: 53 frames
#    cctv052x2004080607x01843: 53 frames
#    cctv052x2004080607x01844: 53 frames
#    cctv052x2004080607x01845: 53 frames
#    cctv052x2004080607x01846: 53 frames
#    cctv052x2004080607x01847: 52 frames
#    cctv052x2004080607x01848: 53 frames
#    cctv052x2004080608x01849: 52 frames
#    cctv052x2004080608x01850: 53 frames
#    cctv052x2004080608x01851: 51 frames
#    cctv052x2004080608x01852: 53 frames
#    cctv052x2004080608x01853: 52 frames
#    cctv052x2004080608x01854: 53 frames
#    cctv052x2004080608x01855: 50 frames
#    cctv052x2004080608x01856: 53 frames
#    cctv052x2004080608x01857: 53 frames
#    cctv052x2004080608x01858: 53 frames
#    cctv052x2004080609x01859: 53 frames
#    cctv052x2004080609x01860: 52 frames
#    cctv052x2004080609x01861: 52 frames
#    cctv052x2004080609x01862: 52 frames
#    cctv052x2004080609x01863: 53 frames
#    cctv052x2004080609x01864: 52 frames
#    cctv052x2004080609x01865: 53 frames
#    cctv052x2004080609x01866: 50 frames
#    cctv052x2004080609x01867: 53 frames
#    cctv052x2004080609x01869: 50 frames
#    cctv052x2004080609x01870: 53 frames
#    cctv052x2004080609x01871: 53 frames
#    cctv052x2004080609x01872: 53 frames
#    cctv052x2004080609x01873: 53 frames
#    cctv052x2004080609x01874: 52 frames
#    cctv052x2004080609x01875: 52 frames
#    cctv052x2004080609x01876: 53 frames
#    cctv052x2004080610x01877: 51 frames
#    cctv052x2004080610x01878: 53 frames
#    cctv052x2004080610x01879: 53 frames
#    cctv052x2004080610x01880: 53 frames
#    cctv052x2004080610x01881: 53 frames
#    cctv052x2004080610x01882: 53 frames
#    cctv052x2004080610x01883: 53 frames
#    cctv052x2004080610x01884: 50 frames
#    cctv052x2004080610x01885: 53 frames
#    cctv052x2004080610x01886: 53 frames
#    cctv052x2004080610x01887: 53 frames
#    cctv052x2004080610x01889: 51 frames
#    cctv052x2004080610x01890: 52 frames
#    cctv052x2004080610x01891: 52 frames
#    cctv052x2004080610x01892: 53 frames
#    cctv052x2004080611x01894: 53 frames
#    cctv052x2004080611x01895: 53 frames
#    cctv052x2004080611x01896: 53 frames
#    cctv052x2004080611x01897: 53 frames
#    cctv052x2004080611x01898: 53 frames
#    cctv052x2004080611x01899: 53 frames
#    cctv052x2004080611x01900: 51 frames
#    cctv052x2004080611x01901: 52 frames
#    cctv052x2004080611x01902: 53 frames
#    cctv052x2004080611x01903: 53 frames
#    cctv052x2004080611x01904: 53 frames
#    cctv052x2004080611x01905: 53 frames
#    cctv052x2004080611x01906: 53 frames
#    cctv052x2004080611x01907: 52 frames
#    cctv052x2004080612x00000: 53 frames
#    cctv052x2004080612x00002: 53 frames
#    cctv052x2004080612x00003: 50 frames
#    cctv052x2004080612x00004: 51 frames
#    cctv052x2004080612x00005: 53 frames
#    cctv052x2004080612x00006: 53 frames
#    cctv052x2004080612x00007: 52 frames
#    cctv052x2004080612x01908: 53 frames
#    cctv052x2004080612x01909: 53 frames
#    cctv052x2004080612x01910: 53 frames
#    cctv052x2004080612x01911: 48 frames
#    cctv052x2004080612x01912: 53 frames
#    cctv052x2004080612x01913: 53 frames
#    cctv052x2004080612x01914: 53 frames
#    cctv052x2004080612x01915: 53 frames
#    cctv052x2004080613x00008: 51 frames
#    cctv052x2004080613x00009: 52 frames
#    cctv052x2004080613x00010: 53 frames
#    cctv052x2004080613x00011: 53 frames
#    cctv052x2004080613x00012: 53 frames
#    cctv052x2004080613x00013: 53 frames
#    cctv052x2004080613x00014: 53 frames
#    cctv052x2004080613x00015: 53 frames
#    cctv052x2004080613x00016: 50 frames
#    cctv052x2004080613x00017: 53 frames
#    cctv052x2004080613x00018: 53 frames
#    cctv052x2004080614x00019: 53 frames
#    cctv052x2004080614x00020: 53 frames
#    cctv052x2004080614x00021: 52 frames
#    cctv052x2004080614x00022: 53 frames
#    cctv052x2004080614x00023: 52 frames
#    cctv052x2004080614x00024: 53 frames
#    cctv052x2004080614x00025: 53 frames
#    cctv052x2004080614x00026: 53 frames
#    cctv052x2004080614x00027: 53 frames
#    cctv052x2004080615x00028: 53 frames
#    cctv052x2004080615x00029: 52 frames
#    cctv052x2004080615x00030: 53 frames
#    cctv052x2004080615x00031: 53 frames
#    cctv052x2004080615x00032: 53 frames
#    cctv052x2004080615x00033: 53 frames
#    cctv052x2004080615x00034: 53 frames
#    cctv052x2004080615x00035: 53 frames
#    cctv052x2004080615x00036: 53 frames
#    cctv052x2004080615x00037: 53 frames
#    cctv052x2004080615x00038: 53 frames
#    cctv052x2004080615x00039: 53 frames
#    cctv052x2004080615x00040: 53 frames
#    cctv052x2004080615x00041: 53 frames
#    cctv052x2004080615x00044: 53 frames
#    cctv052x2004080615x00045: 53 frames
#    cctv052x2004080616x00046: 53 frames
#    cctv052x2004080616x00047: 53 frames
#    cctv052x2004080616x00048: 49 frames
#    cctv052x2004080616x00049: 44 frames
#    cctv052x2004080616x00050: 50 frames
#    cctv052x2004080616x00051: 53 frames
#    cctv052x2004080616x00052: 53 frames
#    cctv052x2004080616x00053: 53 frames
#    cctv052x2004080616x00054: 53 frames
#    cctv052x2004080616x00055: 53 frames
#    cctv052x2004080616x00056: 53 frames
#    cctv052x2004080616x00057: 53 frames
#    cctv052x2004080616x00058: 53 frames
#    cctv052x2004080616x00059: 48 frames
#    cctv052x2004080616x00060: 53 frames
#    cctv052x2004080616x00061: 53 frames
#    cctv052x2004080616x00062: 53 frames
#    cctv052x2004080617x00064: 52 frames
#    cctv052x2004080617x00065: 53 frames
#    cctv052x2004080617x00066: 53 frames
#    cctv052x2004080617x00067: 53 frames
#    cctv052x2004080617x00068: 52 frames
#    cctv052x2004080617x00069: 52 frames
#    cctv052x2004080617x00070: 53 frames
#    cctv052x2004080617x00071: 53 frames
#    cctv052x2004080617x00072: 50 frames
#    cctv052x2004080617x00073: 53 frames
#    cctv052x2004080617x00074: 52 frames
#    cctv052x2004080617x00075: 53 frames
#    cctv052x2004080617x00076: 43 frames
#    cctv052x2004080617x00077: 53 frames
#    cctv052x2004080618x00079: 53 frames
#    cctv052x2004080618x00080: 53 frames
#    cctv052x2004080618x00081: 53 frames
#    cctv052x2004080618x00085: 53 frames
#    cctv052x2004080618x00086: 53 frames
#    cctv052x2004080618x00087: 53 frames
#    cctv052x2004080618x00088: 53 frames
#    cctv052x2004080618x00089: 53 frames
#    cctv052x2004080619x00090: 52 frames
#    cctv052x2004080619x00091: 53 frames
#    cctv052x2004080619x00092: 53 frames
#    cctv052x2004080619x00093: 53 frames
#    cctv052x2004080619x00094: 53 frames
#    cctv052x2004080619x00095: 53 frames
#    cctv052x2004080619x00096: 53 frames
#    cctv052x2004080619x00097: 52 frames
#    cctv052x2004080619x00098: 53 frames
#    cctv052x2004080619x00099: 53 frames
#    cctv052x2004080619x00100: 52 frames
#    cctv052x2004080619x00101: 53 frames
#    cctv052x2004080619x00102: 52 frames
#    cctv052x2004080619x00103: 53 frames
#    cctv052x2004080619x00104: 53 frames
#    cctv052x2004080620x00105: 52 frames
#    cctv052x2004080620x00106: 53 frames
#    cctv052x2004080620x00107: 53 frames
#    cctv052x2004080620x00108: 52 frames

# %%
# Visualize
if raw_frame_info:
    plt.figure(figsize=(10, 5))
    plt.bar(raw_frame_info.keys(), raw_frame_info.values(), color='steelblue', edgecolor='black')
    plt.xlabel('Video Name')
    plt.ylabel('Number of Raw Frames')
    plt.title(f'Raw Frames Extracted (Total: {total_raw_frames})')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, '01_raw_frames_distribution.png'), dpi=150)
    plt.show()
    print(f"\n✅ Chart saved: {OUTPUT_DIR}/01_raw_frames_distribution.png")

print("="*60)
# Out:
# ✅ Chart saved: /content/results/01_raw_frames_distribution.png
# ============================================================

# %%
def apply_quantization(raw_frames_dir, quantized_frames_dir, skip_interval=3):
    """
    Take every N-th frame from raw extracted frames
    Creates a manageable dataset for analysis
    """
    total_quantized = 0

    print("\n" + "="*60)
    print(f"⚡ PHASE 2: APPLYING SMART QUANTIZATION (skip={skip_interval})")
    print("="*60)

    for video_dir in sorted(os.listdir(raw_frames_dir)):
        raw_video_path = os.path.join(raw_frames_dir, video_dir)
        quantized_video_path = os.path.join(quantized_frames_dir, video_dir)

        if not os.path.isdir(raw_video_path):
            continue

        os.makedirs(quantized_video_path, exist_ok=True)

        # Get all frames in raw directory
        raw_frames = sorted([f for f in os.listdir(raw_video_path) if f.endswith('.jpg')])

        # Apply quantization (take every N-th frame)
        quantized_count = 0
        for idx, frame_file in enumerate(raw_frames):
            if idx % skip_interval == 0:
                src_path = os.path.join(raw_video_path, frame_file)
                dst_path = os.path.join(quantized_video_path, f"frame_{quantized_count:05d}.jpg")

                # Copy (don't re-process to save time)
                shutil.copy2(src_path, dst_path)
                quantized_count += 1

        total_quantized += quantized_count
        compression_ratio = len(raw_frames) / quantized_count if quantized_count > 0 else 0
        data_retained = (quantized_count / len(raw_frames) * 100) if len(raw_frames) > 0 else 0

        print(f"\n   📹 {video_dir}")
        print(f"      Raw frames: {len(raw_frames)}")
        print(f"      Quantized frames: {quantized_count}")
        print(f"      Compression ratio: {compression_ratio:.2f}:1")
        print(f"      Data retained: {data_retained:.1f}%")

    return total_quantized

# %%
quantized_frames_count = apply_quantization(FRAMES_RAW_DIR, FRAMES_QUANTIZED_DIR, FRAME_SKIP_FOR_QUANTIZATION)

print("\n" + "="*60)
print(f"✅ PHASE 2 COMPLETE - QUANTIZATION APPLIED")
print("="*60)
print(f"📊 Total RAW frames: {total_raw_frames}")
print(f"📊 Total QUANTIZED frames: {quantized_frames_count}")
print(f"📊 Compression ratio: {total_raw_frames/quantized_frames_count:.2f}:1")
print(f"📊 Data retained: {quantized_frames_count/total_raw_frames*100:.1f}%")
print("="*60)
# Out:
# ============================================================
# ⚡ PHASE 2: APPLYING SMART QUANTIZATION (skip=3)
# ============================================================
#
#    📹 cctv052x2004080516x01638
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01639
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01640
#       Raw frames: 48
#       Quantized frames: 16
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080516x01641
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080516x01642
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080516x01643
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01644
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01645
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080516x01646
#       Raw frames: 49
#       Quantized frames: 17
#       Compression ratio: 2.88:1
#       Data retained: 34.7%
#
#    📹 cctv052x2004080516x01647
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080516x01648
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01649
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080516x01650
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01652
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01653
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01654
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01655
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01656
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01657
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01658
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01659
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01660
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01661
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01662
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01663
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080517x01664
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080517x01665
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01666
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080518x01667
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080518x01668
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01669
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01670
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080518x01671
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01672
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01673
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080518x01674
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01675
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01676
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080518x01677
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01678
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01679
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01680
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01681
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01682
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01683
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080519x01684
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01685
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01686
#       Raw frames: 49
#       Quantized frames: 17
#       Compression ratio: 2.88:1
#       Data retained: 34.7%
#
#    📹 cctv052x2004080519x01687
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080519x01688
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080519x01689
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080519x01690
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080519x01691
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080519x01692
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080519x01693
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080520x01694
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080520x01695
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080520x01697
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080520x01698
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080520x01699
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080520x01700
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01820
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01821
#       Raw frames: 47
#       Quantized frames: 16
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01822
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01823
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080606x01824
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01826
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01827
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01828
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080606x01829
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01830
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080606x01831
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01832
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01833
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080606x01834
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01835
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01836
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01837
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01838
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01839
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01840
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080607x01841
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01842
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01843
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01844
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01845
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01846
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080607x01847
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080607x01848
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01849
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080608x01850
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01851
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080608x01852
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01853
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080608x01854
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01855
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01856
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01857
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080608x01858
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01859
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01860
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01861
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01862
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01863
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01864
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01865
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01866
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01867
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01869
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01870
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01871
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01872
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01873
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080609x01874
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01875
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080609x01876
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01877
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080610x01878
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01879
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01880
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01881
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01882
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01883
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01884
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01885
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01886
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01887
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080610x01889
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080610x01890
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080610x01891
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080610x01892
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01894
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01895
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01896
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01897
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01898
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01899
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01900
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080611x01901
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080611x01902
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01903
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01904
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01905
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01906
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080611x01907
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080612x00000
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x00002
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x00003
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x00004
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080612x00005
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x00006
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x00007
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080612x01908
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01909
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01910
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01911
#       Raw frames: 48
#       Quantized frames: 16
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080612x01912
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01913
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01914
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080612x01915
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00008
#       Raw frames: 51
#       Quantized frames: 17
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080613x00009
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080613x00010
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00011
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00012
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00013
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00014
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00015
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00016
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00017
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080613x00018
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00019
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00020
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00021
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080614x00022
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00023
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080614x00024
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00025
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00026
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080614x00027
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00028
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00029
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080615x00030
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00031
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00032
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00033
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00034
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00035
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00036
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00037
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00038
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00039
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00040
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00041
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00044
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080615x00045
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00046
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00047
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00048
#       Raw frames: 49
#       Quantized frames: 17
#       Compression ratio: 2.88:1
#       Data retained: 34.7%
#
#    📹 cctv052x2004080616x00049
#       Raw frames: 44
#       Quantized frames: 15
#       Compression ratio: 2.93:1
#       Data retained: 34.1%
#
#    📹 cctv052x2004080616x00050
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00051
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00052
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00053
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00054
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00055
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00056
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00057
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00058
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00059
#       Raw frames: 48
#       Quantized frames: 16
#       Compression ratio: 3.00:1
#       Data retained: 33.3%
#
#    📹 cctv052x2004080616x00060
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00061
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080616x00062
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00064
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080617x00065
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00066
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00067
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00068
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080617x00069
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080617x00070
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00071
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00072
#       Raw frames: 50
#       Quantized frames: 17
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00073
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00074
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080617x00075
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080617x00076
#       Raw frames: 43
#       Quantized frames: 15
#       Compression ratio: 2.87:1
#       Data retained: 34.9%
#
#    📹 cctv052x2004080617x00077
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00079
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00080
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00081
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00085
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00086
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00087
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00088
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080618x00089
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00090
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080619x00091
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00092
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00093
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00094
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00095
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00096
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00097
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080619x00098
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00099
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00100
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080619x00101
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00102
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080619x00103
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080619x00104
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080620x00105
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
#    📹 cctv052x2004080620x00106
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080620x00107
#       Raw frames: 53
#       Quantized frames: 18
#       Compression ratio: 2.94:1
#       Data retained: 34.0%
#
#    📹 cctv052x2004080620x00108
#       Raw frames: 52
#       Quantized frames: 18
#       Compression ratio: 2.89:1
#       Data retained: 34.6%
#
# ============================================================
# ✅ PHASE 2 COMPLETE - QUANTIZATION APPLIED
# ============================================================
# 📊 Total RAW frames: 13317
# 📊 Total QUANTIZED frames: 4535
# 📊 Compression ratio: 2.94:1
# 📊 Data retained: 34.1%
# ============================================================

# %%
# Count quantized frames
quantized_frame_info = {}
total_quantized_verified = 0

print("\n" + "="*60)
print("📊 VERIFYING QUANTIZED FRAMES")
print("="*60)

for video_dir in sorted(os.listdir(FRAMES_QUANTIZED_DIR)):
    video_path = os.path.join(FRAMES_QUANTIZED_DIR, video_dir)
    if os.path.isdir(video_path):
        frame_count = len([f for f in os.listdir(video_path) if f.endswith('.jpg')])
        quantized_frame_info[video_dir] = frame_count
        total_quantized_verified += frame_count

print(f"\n✅ Total QUANTIZED frames: {total_quantized_verified}")
print("\n📁 Quantized frames per video:")
for video, count in quantized_frame_info.items():
    print(f"   {video}: {count} frames")

# Visualize comparison
if quantized_frame_info and raw_frame_info:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Raw frames
    axes[0].bar(raw_frame_info.keys(), raw_frame_info.values(), color='steelblue', edgecolor='black')
    axes[0].set_ylabel('Number of Frames')
    axes[0].set_title(f'Raw Frames (Total: {total_raw_frames})')
    axes[0].tick_params(axis='x', rotation=45)

    # Quantized frames
    axes[1].bar(quantized_frame_info.keys(), quantized_frame_info.values(), color='coral', edgecolor='black')
    axes[1].set_ylabel('Number of Frames')
    axes[1].set_title(f'Quantized Frames (Total: {total_quantized_verified})')
    axes[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, '02_raw_vs_quantized_comparison.png'), dpi=150)
    plt.show()
    print(f"\n✅ Comparison chart saved: {OUTPUT_DIR}/02_raw_vs_quantized_comparison.png")

print("="*60)
# Out:
# ============================================================
# 📊 VERIFYING QUANTIZED FRAMES
# ============================================================
#
# ✅ Total QUANTIZED frames: 4535
#
# 📁 Quantized frames per video:
#    cctv052x2004080516x01638: 18 frames
#    cctv052x2004080516x01639: 18 frames
#    cctv052x2004080516x01640: 16 frames
#    cctv052x2004080516x01641: 18 frames
#    cctv052x2004080516x01642: 17 frames
#    cctv052x2004080516x01643: 18 frames
#    cctv052x2004080516x01644: 18 frames
#    cctv052x2004080516x01645: 18 frames
#    cctv052x2004080516x01646: 17 frames
#    cctv052x2004080516x01647: 18 frames
#    cctv052x2004080516x01648: 18 frames
#    cctv052x2004080516x01649: 18 frames
#    cctv052x2004080516x01650: 18 frames
#    cctv052x2004080517x01652: 18 frames
#    cctv052x2004080517x01653: 18 frames
#    cctv052x2004080517x01654: 18 frames
#    cctv052x2004080517x01655: 18 frames
#    cctv052x2004080517x01656: 18 frames
#    cctv052x2004080517x01657: 18 frames
#    cctv052x2004080517x01658: 18 frames
#    cctv052x2004080517x01659: 18 frames
#    cctv052x2004080517x01660: 18 frames
#    cctv052x2004080517x01661: 18 frames
#    cctv052x2004080517x01662: 18 frames
#    cctv052x2004080517x01663: 18 frames
#    cctv052x2004080517x01664: 18 frames
#    cctv052x2004080517x01665: 18 frames
#    cctv052x2004080518x01666: 17 frames
#    cctv052x2004080518x01667: 17 frames
#    cctv052x2004080518x01668: 18 frames
#    cctv052x2004080518x01669: 18 frames
#    cctv052x2004080518x01670: 18 frames
#    cctv052x2004080518x01671: 18 frames
#    cctv052x2004080518x01672: 18 frames
#    cctv052x2004080518x01673: 18 frames
#    cctv052x2004080518x01674: 18 frames
#    cctv052x2004080518x01675: 18 frames
#    cctv052x2004080518x01676: 18 frames
#    cctv052x2004080518x01677: 18 frames
#    cctv052x2004080519x01678: 18 frames
#    cctv052x2004080519x01679: 18 frames
#    cctv052x2004080519x01680: 18 frames
#    cctv052x2004080519x01681: 18 frames
#    cctv052x2004080519x01682: 18 frames
#    cctv052x2004080519x01683: 18 frames
#    cctv052x2004080519x01684: 18 frames
#    cctv052x2004080519x01685: 18 frames
#    cctv052x2004080519x01686: 17 frames
#    cctv052x2004080519x01687: 18 frames
#    cctv052x2004080519x01688: 18 frames
#    cctv052x2004080519x01689: 18 frames
#    cctv052x2004080519x01690: 18 frames
#    cctv052x2004080519x01691: 18 frames
#    cctv052x2004080519x01692: 17 frames
#    cctv052x2004080519x01693: 18 frames
#    cctv052x2004080520x01694: 18 frames
#    cctv052x2004080520x01695: 18 frames
#    cctv052x2004080520x01697: 18 frames
#    cctv052x2004080520x01698: 17 frames
#    cctv052x2004080520x01699: 18 frames
#    cctv052x2004080520x01700: 18 frames
#    cctv052x2004080606x01820: 18 frames
#    cctv052x2004080606x01821: 16 frames
#    cctv052x2004080606x01822: 18 frames
#    cctv052x2004080606x01823: 18 frames
#    cctv052x2004080606x01824: 18 frames
#    cctv052x2004080606x01826: 18 frames
#    cctv052x2004080606x01827: 17 frames
#    cctv052x2004080606x01828: 18 frames
#    cctv052x2004080606x01829: 18 frames
#    cctv052x2004080606x01830: 18 frames
#    cctv052x2004080606x01831: 18 frames
#    cctv052x2004080606x01832: 18 frames
#    cctv052x2004080606x01833: 18 frames
#    cctv052x2004080606x01834: 18 frames
#    cctv052x2004080607x01835: 18 frames
#    cctv052x2004080607x01836: 18 frames
#    cctv052x2004080607x01837: 18 frames
#    cctv052x2004080607x01838: 18 frames
#    cctv052x2004080607x01839: 18 frames
#    cctv052x2004080607x01840: 18 frames
#    cctv052x2004080607x01841: 18 frames
#    cctv052x2004080607x01842: 18 frames
#    cctv052x2004080607x01843: 18 frames
#    cctv052x2004080607x01844: 18 frames
#    cctv052x2004080607x01845: 18 frames
#    cctv052x2004080607x01846: 18 frames
#    cctv052x2004080607x01847: 18 frames
#    cctv052x2004080607x01848: 18 frames
#    cctv052x2004080608x01849: 18 frames
#    cctv052x2004080608x01850: 18 frames
#    cctv052x2004080608x01851: 17 frames
#    cctv052x2004080608x01852: 18 frames
#    cctv052x2004080608x01853: 18 frames
#    cctv052x2004080608x01854: 18 frames
#    cctv052x2004080608x01855: 17 frames
#    cctv052x2004080608x01856: 18 frames
#    cctv052x2004080608x01857: 18 frames
#    cctv052x2004080608x01858: 18 frames
#    cctv052x2004080609x01859: 18 frames
#    cctv052x2004080609x01860: 18 frames
#    cctv052x2004080609x01861: 18 frames
#    cctv052x2004080609x01862: 18 frames
#    cctv052x2004080609x01863: 18 frames
#    cctv052x2004080609x01864: 18 frames
#    cctv052x2004080609x01865: 18 frames
#    cctv052x2004080609x01866: 17 frames
#    cctv052x2004080609x01867: 18 frames
#    cctv052x2004080609x01869: 17 frames
#    cctv052x2004080609x01870: 18 frames
#    cctv052x2004080609x01871: 18 frames
#    cctv052x2004080609x01872: 18 frames
#    cctv052x2004080609x01873: 18 frames
#    cctv052x2004080609x01874: 18 frames
#    cctv052x2004080609x01875: 18 frames
#    cctv052x2004080609x01876: 18 frames
#    cctv052x2004080610x01877: 17 frames
#    cctv052x2004080610x01878: 18 frames
#    cctv052x2004080610x01879: 18 frames
#    cctv052x2004080610x01880: 18 frames
#    cctv052x2004080610x01881: 18 frames
#    cctv052x2004080610x01882: 18 frames
#    cctv052x2004080610x01883: 18 frames
#    cctv052x2004080610x01884: 17 frames
#    cctv052x2004080610x01885: 18 frames
#    cctv052x2004080610x01886: 18 frames
#    cctv052x2004080610x01887: 18 frames
#    cctv052x2004080610x01889: 17 frames
#    cctv052x2004080610x01890: 18 frames
#    cctv052x2004080610x01891: 18 frames
#    cctv052x2004080610x01892: 18 frames
#    cctv052x2004080611x01894: 18 frames
#    cctv052x2004080611x01895: 18 frames
#    cctv052x2004080611x01896: 18 frames
#    cctv052x2004080611x01897: 18 frames
#    cctv052x2004080611x01898: 18 frames
#    cctv052x2004080611x01899: 18 frames
#    cctv052x2004080611x01900: 17 frames
#    cctv052x2004080611x01901: 18 frames
#    cctv052x2004080611x01902: 18 frames
#    cctv052x2004080611x01903: 18 frames
#    cctv052x2004080611x01904: 18 frames
#    cctv052x2004080611x01905: 18 frames
#    cctv052x2004080611x01906: 18 frames
#    cctv052x2004080611x01907: 18 frames
#    cctv052x2004080612x00000: 18 frames
#    cctv052x2004080612x00002: 18 frames
#    cctv052x2004080612x00003: 17 frames
#    cctv052x2004080612x00004: 17 frames
#    cctv052x2004080612x00005: 18 frames
#    cctv052x2004080612x00006: 18 frames
#    cctv052x2004080612x00007: 18 frames
#    cctv052x2004080612x01908: 18 frames
#    cctv052x2004080612x01909: 18 frames
#    cctv052x2004080612x01910: 18 frames
#    cctv052x2004080612x01911: 16 frames
#    cctv052x2004080612x01912: 18 frames
#    cctv052x2004080612x01913: 18 frames
#    cctv052x2004080612x01914: 18 frames
#    cctv052x2004080612x01915: 18 frames
#    cctv052x2004080613x00008: 17 frames
#    cctv052x2004080613x00009: 18 frames
#    cctv052x2004080613x00010: 18 frames
#    cctv052x2004080613x00011: 18 frames
#    cctv052x2004080613x00012: 18 frames
#    cctv052x2004080613x00013: 18 frames
#    cctv052x2004080613x00014: 18 frames
#    cctv052x2004080613x00015: 18 frames
#    cctv052x2004080613x00016: 17 frames
#    cctv052x2004080613x00017: 18 frames
#    cctv052x2004080613x00018: 18 frames
#    cctv052x2004080614x00019: 18 frames
#    cctv052x2004080614x00020: 18 frames
#    cctv052x2004080614x00021: 18 frames
#    cctv052x2004080614x00022: 18 frames
#    cctv052x2004080614x00023: 18 frames
#    cctv052x2004080614x00024: 18 frames
#    cctv052x2004080614x00025: 18 frames
#    cctv052x2004080614x00026: 18 frames
#    cctv052x2004080614x00027: 18 frames
#    cctv052x2004080615x00028: 18 frames
#    cctv052x2004080615x00029: 18 frames
#    cctv052x2004080615x00030: 18 frames
#    cctv052x2004080615x00031: 18 frames
#    cctv052x2004080615x00032: 18 frames
#    cctv052x2004080615x00033: 18 frames
#    cctv052x2004080615x00034: 18 frames
#    cctv052x2004080615x00035: 18 frames
#    cctv052x2004080615x00036: 18 frames
#    cctv052x2004080615x00037: 18 frames
#    cctv052x2004080615x00038: 18 frames
#    cctv052x2004080615x00039: 18 frames
#    cctv052x2004080615x00040: 18 frames
#    cctv052x2004080615x00041: 18 frames
#    cctv052x2004080615x00044: 18 frames
#    cctv052x2004080615x00045: 18 frames
#    cctv052x2004080616x00046: 18 frames
#    cctv052x2004080616x00047: 18 frames
#    cctv052x2004080616x00048: 17 frames
#    cctv052x2004080616x00049: 15 frames
#    cctv052x2004080616x00050: 17 frames
#    cctv052x2004080616x00051: 18 frames
#    cctv052x2004080616x00052: 18 frames
#    cctv052x2004080616x00053: 18 frames
#    cctv052x2004080616x00054: 18 frames
#    cctv052x2004080616x00055: 18 frames
#    cctv052x2004080616x00056: 18 frames
#    cctv052x2004080616x00057: 18 frames
#    cctv052x2004080616x00058: 18 frames
#    cctv052x2004080616x00059: 16 frames
#    cctv052x2004080616x00060: 18 frames
#    cctv052x2004080616x00061: 18 frames
#    cctv052x2004080616x00062: 18 frames
#    cctv052x2004080617x00064: 18 frames
#    cctv052x2004080617x00065: 18 frames
#    cctv052x2004080617x00066: 18 frames
#    cctv052x2004080617x00067: 18 frames
#    cctv052x2004080617x00068: 18 frames
#    cctv052x2004080617x00069: 18 frames
#    cctv052x2004080617x00070: 18 frames
#    cctv052x2004080617x00071: 18 frames
#    cctv052x2004080617x00072: 17 frames
#    cctv052x2004080617x00073: 18 frames
#    cctv052x2004080617x00074: 18 frames
#    cctv052x2004080617x00075: 18 frames
#    cctv052x2004080617x00076: 15 frames
#    cctv052x2004080617x00077: 18 frames
#    cctv052x2004080618x00079: 18 frames
#    cctv052x2004080618x00080: 18 frames
#    cctv052x2004080618x00081: 18 frames
#    cctv052x2004080618x00085: 18 frames
#    cctv052x2004080618x00086: 18 frames
#    cctv052x2004080618x00087: 18 frames
#    cctv052x2004080618x00088: 18 frames
#    cctv052x2004080618x00089: 18 frames
#    cctv052x2004080619x00090: 18 frames
#    cctv052x2004080619x00091: 18 frames
#    cctv052x2004080619x00092: 18 frames
#    cctv052x2004080619x00093: 18 frames
#    cctv052x2004080619x00094: 18 frames
#    cctv052x2004080619x00095: 18 frames
#    cctv052x2004080619x00096: 18 frames
#    cctv052x2004080619x00097: 18 frames
#    cctv052x2004080619x00098: 18 frames
#    cctv052x2004080619x00099: 18 frames
#    cctv052x2004080619x00100: 18 frames
#    cctv052x2004080619x00101: 18 frames
#    cctv052x2004080619x00102: 18 frames
#    cctv052x2004080619x00103: 18 frames
#    cctv052x2004080619x00104: 18 frames
#    cctv052x2004080620x00105: 18 frames
#    cctv052x2004080620x00106: 18 frames
#    cctv052x2004080620x00107: 18 frames
#    cctv052x2004080620x00108: 18 frames
# ✅ Comparison chart saved: /content/results/02_raw_vs_quantized_comparison.png
# ============================================================

# %%
print("\n" + "="*60)
print("📸 DISPLAYING SAMPLE FRAMES")
print("="*60)

video_dirs = [d for d in os.listdir(FRAMES_QUANTIZED_DIR) if os.path.isdir(os.path.join(FRAMES_QUANTIZED_DIR, d))]

if video_dirs:
    sample_dir = os.path.join(FRAMES_QUANTIZED_DIR, video_dirs[0])
    frame_files = sorted([f for f in os.listdir(sample_dir) if f.endswith('.jpg')])

    num_samples = min(6, len(frame_files))

    if num_samples > 0:
        plt.figure(figsize=(18, 3))
        for i in range(num_samples):
            img = Image.open(os.path.join(sample_dir, frame_files[i]))
            plt.subplot(1, num_samples, i+1)
            plt.imshow(img)
            plt.title(f"Frame {i+1}")
            plt.axis('off')
        plt.tight_layout()
        plt.savefig(os.path.join(OUTPUT_DIR, '03_sample_frames.png'), dpi=150)
        plt.show()
        print(f"✅ Displaying {num_samples} sample frames from: {video_dirs[0]}")
        print(f"✅ Sample frames saved: {OUTPUT_DIR}/03_sample_frames.png")
    else:
        print("❌ No frames found in sample directory")
else:
    print("❌ No video directories found")

print("="*60)
# Out:
# ============================================================
# 📸 DISPLAYING SAMPLE FRAMES
# ============================================================
# ✅ Displaying 6 sample frames from: cctv052x2004080610x01877
# ✅ Sample frames saved: /content/results/03_sample_frames.png
# ============================================================

# %%
# CELL: Check Raw Frames Count
raw_frames = sum(len([f for f in os.listdir(os.path.join(FRAMES_RAW_DIR, d)) if f.endswith('.jpg')]) for d in os.listdir(FRAMES_RAW_DIR) if os.path.isdir(os.path.join(FRAMES_RAW_DIR, d)))
print(f"📊 RAW FRAMES: {raw_frames}")


# CELL: Check Quantized Frames Count
quantized_frames = sum(len([f for f in os.listdir(os.path.join(FRAMES_QUANTIZED_DIR, d)) if f.endswith('.jpg')]) for d in os.listdir(FRAMES_QUANTIZED_DIR) if os.path.isdir(os.path.join(FRAMES_QUANTIZED_DIR, d)))
print(f"📊 QUANTIZED FRAMES: {quantized_frames}")


# CELL: Show Both Together
raw_count = sum(len([f for f in os.listdir(os.path.join(FRAMES_RAW_DIR, d)) if f.endswith('.jpg')]) for d in os.listdir(FRAMES_RAW_DIR) if os.path.isdir(os.path.join(FRAMES_RAW_DIR, d)))
quantized_count = sum(len([f for f in os.listdir(os.path.join(FRAMES_QUANTIZED_DIR, d)) if f.endswith('.jpg')]) for d in os.listdir(FRAMES_QUANTIZED_DIR) if os.path.isdir(os.path.join(FRAMES_QUANTIZED_DIR, d)))
print(f"📊 RAW FRAMES: {raw_count} | QUANTIZED FRAMES: {quantized_count} | COMPRESSION: {raw_count/quantized_count:.2f}:1")
# Out:
# 📊 RAW FRAMES: 13317
# 📊 QUANTIZED FRAMES: 4535
# 📊 RAW FRAMES: 13317 | QUANTIZED FRAMES: 4535 | COMPRESSION: 2.94:1

# %%
print("="*60)
print("🤖 LOADING VISION TRANSFORMER MODEL")
print("="*60)

# Setup device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n🖥️  Using device: {device}")

# Load pre-trained Vision Transformer
print("\n📥 Loading ViT model...")
vit_model = timm.create_model('vit_base_patch16_224', pretrained=True, num_classes=0)
vit_model = vit_model.to(device)
vit_model.eval()

# Define image preprocessing for ViT
vit_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

print("✅ Vision Transformer loaded!")
print(f"   Model: vit_base_patch16_224")
print(f"   Device: {device}")
print(f"   Input size: 224x224")
print("="*60)
# Out:
# ============================================================
# 🤖 LOADING VISION TRANSFORMER MODEL
# ============================================================
#
# 🖥️  Using device: cpu
#
# 📥 Loading ViT model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# ✅ Vision Transformer loaded!
#    Model: vit_base_patch16_224
#    Device: cpu
#    Input size: 224x224
# ============================================================

# %%
print("\n" + "="*60)
print("🧠 EXTRACTING FEATURES USING VISION TRANSFORMER")
print("="*60)

vit_features_list = []
vit_frame_paths = []
vit_video_names = []
vit_frame_indices = []
frame_count = 0

for video_dir in sorted(os.listdir(FRAMES_QUANTIZED_DIR)):
    video_path = os.path.join(FRAMES_QUANTIZED_DIR, video_dir)
    if not os.path.isdir(video_path):
        continue

    print(f"\n📹 Processing video: {video_dir}")

    frame_files = sorted([f for f in os.listdir(video_path) if f.endswith('.jpg')])
    total_frames_in_video = len(frame_files)

    for idx, frame_file in enumerate(frame_files):
        frame_path = os.path.join(video_path, frame_file)

        try:
            # Load and preprocess image
            img = Image.open(frame_path).convert('RGB')
            img_tensor = vit_transform(img).unsqueeze(0).to(device)

            # Extract features
            with torch.no_grad():
                features = vit_model.forward_features(img_tensor)
                features = features.cpu().numpy().flatten()

            vit_features_list.append(features)
            vit_frame_paths.append(frame_path)
            vit_video_names.append(video_dir)
            vit_frame_indices.append(idx)
            frame_count += 1

            if frame_count % 500 == 0:
                print(f"   ✅ Processed {frame_count} frames...")

        except Exception as e:
            print(f"   ⚠️  Error processing {frame_file}: {e}")
            continue

print("\n" + "="*60)
print(f"✅ FEATURE EXTRACTION COMPLETE")
print(f"   Total frames processed: {len(vit_features_list)}")
print(f"   Feature vector shape: {vit_features_list[0].shape if vit_features_list else 'N/A'}")
print("="*60)
# Out:
# ============================================================
# 🧠 EXTRACTING FEATURES USING VISION TRANSFORMER
# ============================================================
#
# 📹 Processing video: cctv052x2004080516x01638
#
# 📹 Processing video: cctv052x2004080516x01639
#
# 📹 Processing video: cctv052x2004080516x01640
#
# 📹 Processing video: cctv052x2004080516x01641
#
# 📹 Processing video: cctv052x2004080516x01642
#
# 📹 Processing video: cctv052x2004080516x01643
#
# 📹 Processing video: cctv052x2004080516x01644
#
# 📹 Processing video: cctv052x2004080516x01645
#
# 📹 Processing video: cctv052x2004080516x01646
#
# 📹 Processing video: cctv052x2004080516x01647
#
# 📹 Processing video: cctv052x2004080516x01648
#
# 📹 Processing video: cctv052x2004080516x01649
#
# 📹 Processing video: cctv052x2004080516x01650
#
# 📹 Processing video: cctv052x2004080517x01652
#
# 📹 Processing video: cctv052x2004080517x01653
#
# 📹 Processing video: cctv052x2004080517x01654
#
# 📹 Processing video: cctv052x2004080517x01655
#
# 📹 Processing video: cctv052x2004080517x01656
#
# 📹 Processing video: cctv052x2004080517x01657
#
# 📹 Processing video: cctv052x2004080517x01658
#
# 📹 Processing video: cctv052x2004080517x01659
#
# 📹 Processing video: cctv052x2004080517x01660
#
# 📹 Processing video: cctv052x2004080517x01661
#
# 📹 Processing video: cctv052x2004080517x01662
#
# 📹 Processing video: cctv052x2004080517x01663
#
# 📹 Processing video: cctv052x2004080517x01664
#
# 📹 Processing video: cctv052x2004080517x01665
#
# 📹 Processing video: cctv052x2004080518x01666
#
# 📹 Processing video: cctv052x2004080518x01667
#    ✅ Processed 500 frames...
#
# 📹 Processing video: cctv052x2004080518x01668
#
# 📹 Processing video: cctv052x2004080518x01669
#
# 📹 Processing video: cctv052x2004080518x01670
#
# 📹 Processing video: cctv052x2004080518x01671
#
# 📹 Processing video: cctv052x2004080518x01672
#
# 📹 Processing video: cctv052x2004080518x01673
#
# 📹 Processing video: cctv052x2004080518x01674
#
# 📹 Processing video: cctv052x2004080518x01675
#
# 📹 Processing video: cctv052x2004080518x01676
#
# 📹 Processing video: cctv052x2004080518x01677
#
# 📹 Processing video: cctv052x2004080519x01678
#
# 📹 Processing video: cctv052x2004080519x01679
#
# 📹 Processing video: cctv052x2004080519x01680
#
# 📹 Processing video: cctv052x2004080519x01681
#
# 📹 Processing video: cctv052x2004080519x01682
#
# 📹 Processing video: cctv052x2004080519x01683
#
# 📹 Processing video: cctv052x2004080519x01684
#
# 📹 Processing video: cctv052x2004080519x01685
#
# 📹 Processing video: cctv052x2004080519x01686
#
# 📹 Processing video: cctv052x2004080519x01687
#
# 📹 Processing video: cctv052x2004080519x01688
#
# 📹 Processing video: cctv052x2004080519x01689
#
# 📹 Processing video: cctv052x2004080519x01690
#
# 📹 Processing video: cctv052x2004080519x01691
#
# 📹 Processing video: cctv052x2004080519x01692
#
# 📹 Processing video: cctv052x2004080519x01693
#
# 📹 Processing video: cctv052x2004080520x01694
#    ✅ Processed 1000 frames...
#
# 📹 Processing video: cctv052x2004080520x01695
#
# 📹 Processing video: cctv052x2004080520x01697
#
# 📹 Processing video: cctv052x2004080520x01698
#
# 📹 Processing video: cctv052x2004080520x01699
#
# 📹 Processing video: cctv052x2004080520x01700
#
# 📹 Processing video: cctv052x2004080606x01820
#
# 📹 Processing video: cctv052x2004080606x01821
#
# 📹 Processing video: cctv052x2004080606x01822
#
# 📹 Processing video: cctv052x2004080606x01823
#
# 📹 Processing video: cctv052x2004080606x01824
#
# 📹 Processing video: cctv052x2004080606x01826
#
# 📹 Processing video: cctv052x2004080606x01827
#
# 📹 Processing video: cctv052x2004080606x01828
#
# 📹 Processing video: cctv052x2004080606x01829
#
# 📹 Processing video: cctv052x2004080606x01830
#
# 📹 Processing video: cctv052x2004080606x01831
#
# 📹 Processing video: cctv052x2004080606x01832
#
# 📹 Processing video: cctv052x2004080606x01833
#
# 📹 Processing video: cctv052x2004080606x01834
#
# 📹 Processing video: cctv052x2004080607x01835
#
# 📹 Processing video: cctv052x2004080607x01836
#
# 📹 Processing video: cctv052x2004080607x01837
#
# 📹 Processing video: cctv052x2004080607x01838
#
# 📹 Processing video: cctv052x2004080607x01839
#
# 📹 Processing video: cctv052x2004080607x01840
#
# 📹 Processing video: cctv052x2004080607x01841
#
# 📹 Processing video: cctv052x2004080607x01842
#
# 📹 Processing video: cctv052x2004080607x01843
#    ✅ Processed 1500 frames...
#
# 📹 Processing video: cctv052x2004080607x01844
#
# 📹 Processing video: cctv052x2004080607x01845
#
# 📹 Processing video: cctv052x2004080607x01846
#
# 📹 Processing video: cctv052x2004080607x01847
#
# 📹 Processing video: cctv052x2004080607x01848
#
# 📹 Processing video: cctv052x2004080608x01849
#
# 📹 Processing video: cctv052x2004080608x01850
#
# 📹 Processing video: cctv052x2004080608x01851
#
# 📹 Processing video: cctv052x2004080608x01852
#
# 📹 Processing video: cctv052x2004080608x01853
#
# 📹 Processing video: cctv052x2004080608x01854
#
# 📹 Processing video: cctv052x2004080608x01855
#
# 📹 Processing video: cctv052x2004080608x01856
#
# 📹 Processing video: cctv052x2004080608x01857
#
# 📹 Processing video: cctv052x2004080608x01858
#
# 📹 Processing video: cctv052x2004080609x01859
#
# 📹 Processing video: cctv052x2004080609x01860
#
# 📹 Processing video: cctv052x2004080609x01861
#
# 📹 Processing video: cctv052x2004080609x01862
#
# 📹 Processing video: cctv052x2004080609x01863
#
# 📹 Processing video: cctv052x2004080609x01864
#
# 📹 Processing video: cctv052x2004080609x01865
#
# 📹 Processing video: cctv052x2004080609x01866
#
# 📹 Processing video: cctv052x2004080609x01867
#
# 📹 Processing video: cctv052x2004080609x01869
#
# 📹 Processing video: cctv052x2004080609x01870
#
# 📹 Processing video: cctv052x2004080609x01871
#
# 📹 Processing video: cctv052x2004080609x01872
#    ✅ Processed 2000 frames...
#
# 📹 Processing video: cctv052x2004080609x01873
#
# 📹 Processing video: cctv052x2004080609x01874
#
# 📹 Processing video: cctv052x2004080609x01875
#
# 📹 Processing video: cctv052x2004080609x01876
#
# 📹 Processing video: cctv052x2004080610x01877
#
# 📹 Processing video: cctv052x2004080610x01878
#
# 📹 Processing video: cctv052x2004080610x01879
#
# 📹 Processing video: cctv052x2004080610x01880
#
# 📹 Processing video: cctv052x2004080610x01881
#
# 📹 Processing video: cctv052x2004080610x01882
#
# 📹 Processing video: cctv052x2004080610x01883
#
# 📹 Processing video: cctv052x2004080610x01884
#
# 📹 Processing video: cctv052x2004080610x01885
#
# 📹 Processing video: cctv052x2004080610x01886
#
# 📹 Processing video: cctv052x2004080610x01887
#
# 📹 Processing video: cctv052x2004080610x01889
#
# 📹 Processing video: cctv052x2004080610x01890
#
# 📹 Processing video: cctv052x2004080610x01891
#
# 📹 Processing video: cctv052x2004080610x01892
#
# 📹 Processing video: cctv052x2004080611x01894
#
# 📹 Processing video: cctv052x2004080611x01895
#
# 📹 Processing video: cctv052x2004080611x01896
#
# 📹 Processing video: cctv052x2004080611x01897
#
# 📹 Processing video: cctv052x2004080611x01898
#
# 📹 Processing video: cctv052x2004080611x01899
#
# 📹 Processing video: cctv052x2004080611x01900
#
# 📹 Processing video: cctv052x2004080611x01901
#
# 📹 Processing video: cctv052x2004080611x01902
#    ✅ Processed 2500 frames...
#
# 📹 Processing video: cctv052x2004080611x01903
#
# 📹 Processing video: cctv052x2004080611x01904
#
# 📹 Processing video: cctv052x2004080611x01905
#
# 📹 Processing video: cctv052x2004080611x01906
#
# 📹 Processing video: cctv052x2004080611x01907
#
# 📹 Processing video: cctv052x2004080612x00000
#
# 📹 Processing video: cctv052x2004080612x00002
#
# 📹 Processing video: cctv052x2004080612x00003
#
# 📹 Processing video: cctv052x2004080612x00004
#
# 📹 Processing video: cctv052x2004080612x00005
#
# 📹 Processing video: cctv052x2004080612x00006
#
# 📹 Processing video: cctv052x2004080612x00007
#
# 📹 Processing video: cctv052x2004080612x01908
#
# 📹 Processing video: cctv052x2004080612x01909
#
# 📹 Processing video: cctv052x2004080612x01910
#
# 📹 Processing video: cctv052x2004080612x01911
#
# 📹 Processing video: cctv052x2004080612x01912
#
# 📹 Processing video: cctv052x2004080612x01913
#
# 📹 Processing video: cctv052x2004080612x01914
#
# 📹 Processing video: cctv052x2004080612x01915
#
# 📹 Processing video: cctv052x2004080613x00008
#
# 📹 Processing video: cctv052x2004080613x00009
#
# 📹 Processing video: cctv052x2004080613x00010
#
# 📹 Processing video: cctv052x2004080613x00011
#
# 📹 Processing video: cctv052x2004080613x00012
#
# 📹 Processing video: cctv052x2004080613x00013
#
# 📹 Processing video: cctv052x2004080613x00014
#
# 📹 Processing video: cctv052x2004080613x00015
#
# 📹 Processing video: cctv052x2004080613x00016
#    ✅ Processed 3000 frames...
#
# 📹 Processing video: cctv052x2004080613x00017
#
# 📹 Processing video: cctv052x2004080613x00018
#
# 📹 Processing video: cctv052x2004080614x00019
#
# 📹 Processing video: cctv052x2004080614x00020
#
# 📹 Processing video: cctv052x2004080614x00021
#
# 📹 Processing video: cctv052x2004080614x00022
#
# 📹 Processing video: cctv052x2004080614x00023
#
# 📹 Processing video: cctv052x2004080614x00024
#
# 📹 Processing video: cctv052x2004080614x00025
#
# 📹 Processing video: cctv052x2004080614x00026
#
# 📹 Processing video: cctv052x2004080614x00027
#
# 📹 Processing video: cctv052x2004080615x00028
#
# 📹 Processing video: cctv052x2004080615x00029
#
# 📹 Processing video: cctv052x2004080615x00030
#
# 📹 Processing video: cctv052x2004080615x00031
#
# 📹 Processing video: cctv052x2004080615x00032
#
# 📹 Processing video: cctv052x2004080615x00033
#
# 📹 Processing video: cctv052x2004080615x00034
#
# 📹 Processing video: cctv052x2004080615x00035
#
# 📹 Processing video: cctv052x2004080615x00036
#
# 📹 Processing video: cctv052x2004080615x00037
#
# 📹 Processing video: cctv052x2004080615x00038
#
# 📹 Processing video: cctv052x2004080615x00039
#
# 📹 Processing video: cctv052x2004080615x00040
#
# 📹 Processing video: cctv052x2004080615x00041
#
# 📹 Processing video: cctv052x2004080615x00044
#
# 📹 Processing video: cctv052x2004080615x00045
#    ✅ Processed 3500 frames...
#
# 📹 Processing video: cctv052x2004080616x00046
#
# 📹 Processing video: cctv052x2004080616x00047
#
# 📹 Processing video: cctv052x2004080616x00048
#
# 📹 Processing video: cctv052x2004080616x00049
#
# 📹 Processing video: cctv052x2004080616x00050
#
# 📹 Processing video: cctv052x2004080616x00051
#
# 📹 Processing video: cctv052x2004080616x00052
#
# 📹 Processing video: cctv052x2004080616x00053
#
# 📹 Processing video: cctv052x2004080616x00054
#
# 📹 Processing video: cctv052x2004080616x00055
#
# 📹 Processing video: cctv052x2004080616x00056
#
# 📹 Processing video: cctv052x2004080616x00057
#
# 📹 Processing video: cctv052x2004080616x00058
#
# 📹 Processing video: cctv052x2004080616x00059
#
# 📹 Processing video: cctv052x2004080616x00060
#
# 📹 Processing video: cctv052x2004080616x00061
#
# 📹 Processing video: cctv052x2004080616x00062
#
# 📹 Processing video: cctv052x2004080617x00064
#
# 📹 Processing video: cctv052x2004080617x00065
#
# 📹 Processing video: cctv052x2004080617x00066
#
# 📹 Processing video: cctv052x2004080617x00067
#
# 📹 Processing video: cctv052x2004080617x00068
#
# 📹 Processing video: cctv052x2004080617x00069
#
# 📹 Processing video: cctv052x2004080617x00070
#
# 📹 Processing video: cctv052x2004080617x00071
#
# 📹 Processing video: cctv052x2004080617x00072
#
# 📹 Processing video: cctv052x2004080617x00073
#
# 📹 Processing video: cctv052x2004080617x00074
#
# 📹 Processing video: cctv052x2004080617x00075
#    ✅ Processed 4000 frames...
#
# 📹 Processing video: cctv052x2004080617x00076
#
# 📹 Processing video: cctv052x2004080617x00077
#
# 📹 Processing video: cctv052x2004080618x00079
#
# 📹 Processing video: cctv052x2004080618x00080
#
# 📹 Processing video: cctv052x2004080618x00081
#
# 📹 Processing video: cctv052x2004080618x00085
#
# 📹 Processing video: cctv052x2004080618x00086
#
# 📹 Processing video: cctv052x2004080618x00087
#
# 📹 Processing video: cctv052x2004080618x00088
#
# 📹 Processing video: cctv052x2004080618x00089
#
# 📹 Processing video: cctv052x2004080619x00090
#
# 📹 Processing video: cctv052x2004080619x00091
#
# 📹 Processing video: cctv052x2004080619x00092
#
# 📹 Processing video: cctv052x2004080619x00093
#
# 📹 Processing video: cctv052x2004080619x00094
#
# 📹 Processing video: cctv052x2004080619x00095
#
# 📹 Processing video: cctv052x2004080619x00096
#
# 📹 Processing video: cctv052x2004080619x00097
#
# 📹 Processing video: cctv052x2004080619x00098
#
# 📹 Processing video: cctv052x2004080619x00099
#
# 📹 Processing video: cctv052x2004080619x00100
#
# 📹 Processing video: cctv052x2004080619x00101
#
# 📹 Processing video: cctv052x2004080619x00102
#
# 📹 Processing video: cctv052x2004080619x00103
#
# 📹 Processing video: cctv052x2004080619x00104
#
# 📹 Processing video: cctv052x2004080620x00105
#
# 📹 Processing video: cctv052x2004080620x00106
#
# 📹 Processing video: cctv052x2004080620x00107
#    ✅ Processed 4500 frames...
#
# 📹 Processing video: cctv052x2004080620x00108
#
# ============================================================
# ✅ FEATURE EXTRACTION COMPLETE
#    Total frames processed: 4535
#    Feature vector shape: (151296,)
# ============================================================

# %%
print("\n" + "="*60)
print("📊 NORMALIZING FEATURES")
print("="*60)

if len(vit_features_list) == 0:
    print("❌ No features extracted! Please check previous cells.")
else:
    # Convert to numpy array
    X_vit = np.array(vit_features_list)
    print(f"\n📐 Feature matrix shape: {X_vit.shape}")

    # Normalize features
    vit_scaler = StandardScaler()
    X_vit_scaled = vit_scaler.fit_transform(X_vit)

    print(f"✅ Features normalized!")
    print(f"   Mean: {X_vit_scaled.mean():.6f}")
    print(f"   Std: {X_vit_scaled.std():.6f}")
    print("="*60)
# Out:
# ============================================================
# 📊 NORMALIZING FEATURES
# ============================================================
#
# 📐 Feature matrix shape: (4535, 151296)
# ✅ Features normalized!
#    Mean: -0.000000
#    Std: 1.000000
# ============================================================

# %%
print("\n" + "="*60)
print("🚨 TRAINING ANOMALY DETECTION MODEL")
print("="*60)

# Initialize Isolation Forest
print("\n🌲 Initializing Isolation Forest...")
isolation_forest = IsolationForest(
    contamination=0.05,
    random_state=42,
    n_estimators=100,
    max_samples='auto'
)

# Train model
print("🏋️  Training model on normalized features...")
isolation_forest.fit(X_vit_scaled)

# Get anomaly scores and predictions
anomaly_scores = isolation_forest.decision_function(X_vit_scaled)
anomaly_predictions = isolation_forest.predict(X_vit_scaled)

# Statistics
anomaly_count = np.sum(anomaly_predictions == -1)
normal_count = np.sum(anomaly_predictions == 1)

print("\n" + "="*60)
print("✅ ANOMALY DETECTION COMPLETE")
print(f"   Total frames analyzed: {len(anomaly_scores)}")
print(f"   Anomalies detected: {anomaly_count} ({anomaly_count/len(anomaly_scores)*100:.2f}%)")
print(f"   Normal frames: {normal_count} ({normal_count/len(anomaly_scores)*100:.2f}%)")
print(f"   Score range: [{anomaly_scores.min():.4f}, {anomaly_scores.max():.4f}]")
print("="*60)
# Out:
# ============================================================
# 🚨 TRAINING ANOMALY DETECTION MODEL
# ============================================================
#
# 🌲 Initializing Isolation Forest...
# 🏋️  Training model on normalized features...
#
# ============================================================
# ✅ ANOMALY DETECTION COMPLETE
#    Total frames analyzed: 4535
#    Anomalies detected: 227 (5.01%)
#    Normal frames: 4308 (94.99%)
#    Score range: [-0.1263, 0.0846]
# ============================================================

# %%
print("\n" + "="*60)
print("⏱️  CALCULATING TIMESTAMPS AND CONGESTION LEVELS")
print("="*60)

# Get video FPS from original video
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith(('.avi', '.mp4', '.MOV'))]
video_fps = 30  # Default

if video_files:
    video_path = os.path.join(VIDEO_DIR, video_files[0])
    cap = cv2.VideoCapture(video_path)
    video_fps = cap.get(cv2.CAP_PROP_FPS)
    if video_fps == 0:
        video_fps = 30
    cap.release()

print(f"\n📹 Video FPS: {video_fps}")
print(f"⏱️  Frame interval (quantization): {FRAME_SKIP_FOR_QUANTIZATION}")
time_between_frames = FRAME_SKIP_FOR_QUANTIZATION / video_fps
print(f"⏱️  Time between quantized frames: {time_between_frames:.3f} seconds")
# Out:
# ============================================================
# ⏱️  CALCULATING TIMESTAMPS AND CONGESTION LEVELS
# ============================================================
#
# 📹 Video FPS: 10.0
# ⏱️  Frame interval (quantization): 3
# ⏱️  Time between quantized frames: 0.300 seconds

# %%
# Create frame data with timestamps
all_frames_data = []

for i in range(len(vit_frame_paths)):
    # Calculate timestamp
    timestamp_seconds = i * time_between_frames
    minutes = int(timestamp_seconds // 60)
    seconds = timestamp_seconds % 60
    timestamp_str = f"{minutes:02d}:{seconds:05.2f}"

    # Determine if anomaly
    is_anomaly = (anomaly_predictions[i] == -1)
    anomaly_score = float(anomaly_scores[i])

    frame_data = {
        'frame_index': i,
        'frame_path': vit_frame_paths[i],
        'video_name': vit_video_names[i],
        'timestamp': timestamp_str,
        'timestamp_seconds': timestamp_seconds,
        'anomaly_score': anomaly_score,
        'is_anomaly': is_anomaly
    }

    all_frames_data.append(frame_data)

print(f"\n✅ Timestamps calculated for {len(all_frames_data)} frames")
print("="*60)
# Out:
# ✅ Timestamps calculated for 4535 frames
# ============================================================

# %%
print("\n" + "="*60)
print("🚦 DETERMINING CONGESTION LEVELS")
print("="*60)

# Convert scores to list
all_scores = [frame_data['anomaly_score'] for frame_data in all_frames_data]

# Calculate percentiles for congestion classification
# Lower anomaly scores = more anomalous = higher congestion
low_percentile = np.percentile(all_scores, 33)      # Bottom 33% = HIGH congestion
medium_percentile = np.percentile(all_scores, 66)   # Middle 33% = MEDIUM congestion
# Top 34% = LOW congestion

print(f"\n📊 Anomaly Score Percentiles:")
print(f"   Min score: {min(all_scores):.4f}")
print(f"   33rd percentile (HIGH): {low_percentile:.4f}")
print(f"   66th percentile (MEDIUM): {medium_percentile:.4f}")
print(f"   Max score: {max(all_scores):.4f}")

# Assign congestion levels
for frame_data in all_frames_data:
    score = frame_data['anomaly_score']

    if score <= low_percentile:
        congestion_level = 'HIGH'
    elif score <= medium_percentile:
        congestion_level = 'MEDIUM'
    else:
        congestion_level = 'LOW'

    frame_data['congestion_level'] = congestion_level
# Out:
# ============================================================
# 🚦 DETERMINING CONGESTION LEVELS
# ============================================================
#
# 📊 Anomaly Score Percentiles:
#    Min score: -0.1263
#    33rd percentile (HIGH): 0.0361
#    66th percentile (MEDIUM): 0.0520
#    Max score: 0.0846

# %%
# Count congestion levels
congestion_counts = {
    'HIGH': sum(1 for f in all_frames_data if f['congestion_level'] == 'HIGH'),
    'MEDIUM': sum(1 for f in all_frames_data if f['congestion_level'] == 'MEDIUM'),
    'LOW': sum(1 for f in all_frames_data if f['congestion_level'] == 'LOW')
}

print(f"\n🚦 Congestion Distribution:")
print(f"   HIGH: {congestion_counts['HIGH']} frames ({congestion_counts['HIGH']/len(all_frames_data)*100:.1f}%)")
print(f"   MEDIUM: {congestion_counts['MEDIUM']} frames ({congestion_counts['MEDIUM']/len(all_frames_data)*100:.1f}%)")
print(f"   LOW: {congestion_counts['LOW']} frames ({congestion_counts['LOW']/len(all_frames_data)*100:.1f}%)")
print("="*60)
# Out:
# 🚦 Congestion Distribution:
#    HIGH: 1497 frames (33.0%)
#    MEDIUM: 1496 frames (33.0%)
#    LOW: 1542 frames (34.0%)
# ============================================================

# %%
print("\n" + "="*60)
print("💥 IDENTIFYING POTENTIAL ACCIDENTS")
print("="*60)

# Frames with anomaly scores in bottom 1% = potential accidents
accident_threshold = np.percentile(all_scores, 1)

for frame_data in all_frames_data:
    if frame_data['anomaly_score'] <= accident_threshold:
        frame_data['is_accident'] = True
    else:
        frame_data['is_accident'] = False

accident_count = sum(1 for f in all_frames_data if f['is_accident'])

print(f"\n💥 Accident Detection:")
print(f"   Accident threshold (1st percentile): {accident_threshold:.4f}")
print(f"   Potential accident frames: {accident_count} ({accident_count/len(all_frames_data)*100:.2f}%)")
print("="*60)
# Out:
# ============================================================
# 💥 IDENTIFYING POTENTIAL ACCIDENTS
# ============================================================
#
# 💥 Accident Detection:
#    Accident threshold (1st percentile): -0.0395
#    Potential accident frames: 46 (1.01%)
# ============================================================

# %%
print("\n" + "="*60)
print("📝 GENERATING COMPREHENSIVE JSON REPORT")
print("="*60)

# Prepare frames data for JSON
report_frames = []
for frame_data in all_frames_data:
    frame_id = os.path.basename(frame_data['frame_path']).replace('.jpg', '')

    report_frames.append({
        'frame_id': frame_id,
        'frame_index': frame_data['frame_index'],
        'video': frame_data['video_name'],
        'frame_path': frame_data['frame_path'],
        'timestamp': frame_data['timestamp'],
        'timestamp_seconds': round(frame_data['timestamp_seconds'], 2),
        'anomaly_score': round(float(frame_data['anomaly_score']), 4),
        'is_anomaly': bool(frame_data['is_anomaly']), # Convert numpy.bool_ to Python bool
        'congestion_level': frame_data['congestion_level'],
        'is_accident': bool(frame_data['is_accident']) # Convert numpy.bool_ to Python bool
    })

# Create summary statistics
summary = {
    'total_frames_analyzed': len(all_frames_data),
    'total_raw_frames': total_raw_frames,
    'total_quantized_frames': len(all_frames_data),
    'data_retention_rate': f"{(len(all_frames_data)/total_raw_frames)*100:.1f}%",
    'video_fps': float(video_fps),
    'frame_skip_interval': FRAME_SKIP_FOR_QUANTIZATION,
    'time_between_frames_seconds': round(time_between_frames, 3),
    'anomalies_detected': int(anomaly_count),
    'anomaly_percentage': round(float((anomaly_count/len(all_frames_data))*100), 2), # Cast to float
    'potential_accidents': int(accident_count),
    'accident_percentage': round(float((accident_count/len(all_frames_data))*100), 2), # Cast to float
    'congestion_level_counts': congestion_counts,
    'score_statistics': {
        'min_score': round(float(np.min(all_scores)), 4),
        'max_score': round(float(np.max(all_scores)), 4),
        'mean_score': round(float(np.mean(all_scores)), 4),
        'median_score': round(float(np.median(all_scores)), 4),
        'std_score': round(float(np.std(all_scores)), 4)
    },
    'thresholds': {
        'accident_threshold': round(float(accident_threshold), 4), # Cast to float
        'high_congestion_threshold': round(float(low_percentile), 4), # Cast to float
        'medium_congestion_threshold': round(float(medium_percentile), 4) # Cast to float
    }
}
# Out:
# ============================================================
# 📝 GENERATING COMPREHENSIVE JSON REPORT
# ============================================================

# %%
# Create metadata
metadata = {
    'model_name': 'vit_base_patch16_224',
    'anomaly_detector': 'IsolationForest',
    'contamination_rate': 0.05,
    'feature_extraction_method': 'Vision Transformer',
    'feature_dimension': int(vit_features_list[0].shape[0]) if vit_features_list else 0,
    'device': str(device)
}

# Build final report
comprehensive_report = {
    'metadata': metadata,
    'summary': summary,
    'frames_data': report_frames
}

print(f"\n✅ JSON Report Generated!")
print(f"   Total frames in report: {len(report_frames)}")
print(f"   Anomalies found: {anomaly_count}")
print(f"   Accidents detected: {accident_count}")
print("="*60)
# Out:
# ✅ JSON Report Generated!
#    Total frames in report: 4535
#    Anomalies found: 227
#    Accidents detected: 46
# ============================================================

# %%
print("\n" + "="*60)
print("💾 SAVING JSON REPORT")
print("="*60)

output_file = os.path.join(OUTPUT_DIR, 'traffic_anomaly_detection_report.json')

try:
    # Save JSON
    with open(output_file, 'w') as f:
        json.dump(comprehensive_report, f, indent=2)

    file_size = os.path.getsize(output_file)
    print(f"\n✅ JSON saved successfully!")
    print(f"   Location: {output_file}")
    print(f"   File size: {file_size:,} bytes ({file_size/1024/1024:.2f} MB)")

    # Verify by loading
    with open(output_file, 'r') as f:
        loaded = json.load(f)

    print(f"\n✅ Verification passed!")
    print(f"   Frames in file: {len(loaded['frames_data'])}")
    print(f"   Summary available: {bool(loaded.get('summary'))}")
    print(f"   Metadata available: {bool(loaded.get('metadata'))}")

    # Download file
    print("\n⬇️  Initiating download...")
    from google.colab import files
    files.download(output_file)
    print("✅ Download started!")

except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()

print("="*60)
print("🎉 COMPLETE!")
print("="*60)
# Out:
# ============================================================
# 💾 SAVING JSON REPORT
# ============================================================
#
# ✅ JSON saved successfully!
#    Location: /content/results/traffic_anomaly_detection_report.json
#    File size: 1,770,369 bytes (1.69 MB)
#
# ✅ Verification passed!
#    Frames in file: 4535
#    Summary available: True
#    Metadata available: True
#
# ⬇️  Initiating download...
# ✅ Download started!
# ============================================================
# 🎉 COMPLETE!
# ============================================================

# %%
print("\n" + "="*60)
print("🔍 TOP 10 ANOMALOUS FRAMES WITH TIMESTAMPS")
print("="*60)

# Sort by anomaly score (lowest = most anomalous)
sorted_indices = np.argsort(anomaly_scores)[:10]

print("\nRank | Timestamp | Anomaly Score | Congestion | Frame ID")
print("-" * 60)

for rank, frame_idx in enumerate(sorted_indices, 1):
    timestamp = all_frames_data[frame_idx]['timestamp']
    score = anomaly_scores[frame_idx]
    congestion = all_frames_data[frame_idx]['congestion_level']
    frame_id = os.path.basename(vit_frame_paths[frame_idx])
    is_accident = "💥 ACCIDENT" if all_frames_data[frame_idx]['is_accident'] else ""

    print(f"{rank:2d}   | {timestamp:>8s}  | {score:>13.4f} | {congestion:>10s} | {frame_id} {is_accident}")

print("="*60)
print("\n✅ Analysis Complete! JSON report ready for download.")
print("="*60)
# Out:
# ============================================================
# 🔍 TOP 10 ANOMALOUS FRAMES WITH TIMESTAMPS
# ============================================================
#
# Rank | Timestamp | Anomaly Score | Congestion | Frame ID
# ------------------------------------------------------------
#  1   | 19:32.70  |       -0.1263 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  2   | 16:25.80  |       -0.1213 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  3   | 17:41.40  |       -0.1185 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  4   | 16:47.40  |       -0.1130 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  5   | 18:39.30  |       -0.1120 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  6   | 16:36.60  |       -0.1083 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  7   | 19:43.50  |       -0.1046 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  8   | 17:30.60  |       -0.0953 |       HIGH | frame_00000.jpg 💥 ACCIDENT
#  9   | 16:15.00  |       -0.0851 |       HIGH | frame_00000.jpg 💥 ACCIDENT
# 10   | 16:42.00  |       -0.0835 |       HIGH | frame_00000.jpg 💥 ACCIDENT
# ============================================================
#
# ✅ Analysis Complete! JSON report ready for download.
# ============================================================
